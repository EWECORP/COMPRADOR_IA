# %% [markdown]
# # Modelo de Indicadores y Gráficos

# %%
import streamlit as st
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt

# Generar datos simulados
def generar_datos():
    fechas = pd.date_range(start="2024-01-01", periods=12, freq="M")
    categorias = ["Abarrotes", "Bebidas", "Lácteos", "Perecederos"]
    datos = {
        "Fecha": np.tile(fechas, len(categorias)),
        "Categoría": np.repeat(categorias, len(fechas)),
        "Facturación": np.random.randint(500000, 1000000, len(fechas) * len(categorias)),
        "Margen Bruto (%)": np.random.uniform(10, 40, len(fechas) * len(categorias)),
        "Quiebre de Stock (%)": np.random.uniform(2, 8, len(fechas) * len(categorias)),
    }
    return pd.DataFrame(datos)

df = generar_datos()

# Configuración del tablero
st.set_page_config(layout="wide", page_title="Tablero Gerencial DIARCO")

# Títulos
st.title("Tablero Gerencial - Compras y Ventas")
st.markdown("Este tablero muestra indicadores clave para el análisis de Compras y Ventas en DIARCO.")

# Filtros
st.sidebar.header("Filtros")
categoria_seleccionada = st.sidebar.selectbox("Seleccione Categoría", df["Categoría"].unique())
fecha_seleccionada = st.sidebar.slider("Rango de Fechas", 
                                        min_value=df["Fecha"].min(), 
                                        max_value=df["Fecha"].max(), 
                                        value=(df["Fecha"].min(), df["Fecha"].max()))

# Filtrar datos
datos_filtrados = df[
    (df["Categoría"] == categoria_seleccionada) & 
    (df["Fecha"] >= fecha_seleccionada[0]) & 
    (df["Fecha"] <= fecha_seleccionada[1])
]

# Indicadores Clave
st.header("Indicadores Clave")
col1, col2, col3 = st.columns(3)

with col1:
    facturacion_total = datos_filtrados["Facturación"].sum()
    st.metric(label="Facturación Total ($)", value=f"${facturacion_total:,.2f}")

with col2:
    margen_promedio = datos_filtrados["Margen Bruto (%)"].mean()
    st.metric(label="Margen Bruto Promedio (%)", value=f"{margen_promedio:.2f}%")

with col3:
    quiebre_promedio = datos_filtrados["Quiebre de Stock (%)"].mean()
    st.metric(label="Quiebre de Stock Promedio (%)", value=f"{quiebre_promedio:.2f}%")

# Gráficos
st.header("Evolución de Indicadores")

# Facturación por Mes
fig1 = px.line(
    datos_filtrados, 
    x="Fecha", 
    y="Facturación", 
    title="Evolución de la Facturación",
    markers=True,
    labels={"Facturación": "Facturación ($)", "Fecha": "Mes"},
)
st.plotly_chart(fig1, use_container_width=True)

# Margen Bruto por Mes
fig2, ax = plt.subplots()
datos_filtrados.groupby("Fecha")["Margen Bruto (%)"].mean().plot(ax=ax, marker='o', color='green')
ax.axhline(y=margen_promedio, color='red', linestyle='--', label='Meta')
ax.set_title("Margen Bruto Promedio por Mes")
ax.set_xlabel("Mes")
ax.set_ylabel("Margen Bruto (%)")
ax.legend()
st.pyplot(fig2)

# Quiebre de Stock
fig3 = px.bar(
    datos_filtrados, 
    x="Fecha", 
    y="Quiebre de Stock (%)", 
    title="Quiebre de Stock Mensual",
    labels={"Quiebre de Stock (%)": "Quiebre de Stock (%)", "Fecha": "Mes"},
)
st.plotly_chart(fig3, use_container_width=True)

# Comentarios adicionales
st.sidebar.markdown("## Metas")
st.sidebar.text("Facturación: $800,000 por mes")
st.sidebar.text("Margen Bruto: 25% promedio")
st.sidebar.text("Quiebre de Stock: Máximo 3%")

# Footer
st.markdown("Desarrollado por el equipo de sistemas.")
# Out:
# C:\Users\eduar\AppData\Local\Temp\ipykernel_17268\1885119578.py:9: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   fechas = pd.date_range(start="2024-01-01", periods=12, freq="M")
# 2025-01-17 11:53:41.586 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-17 11:53:41.588 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-17 11:53:42.170
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\PY\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-01-17 11:53:42.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-17 11:53:42.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-17 11:53:42.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-17 11:53:42.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-17 11:53:42.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-17 11:53:42.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-17 11:53:42.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-17 11:53:42.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-17 11:53:42.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-17 11:53:42.185 Session state does not function when running a script without `streamlit run`
# 2025-01-17 11:53:42.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-17 11:53:42.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-17 11:53:42.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-17 11:53:42.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-17 11:53:42.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 32
#      30 st.sidebar.header("Filtros")
#      31 categoria_seleccionada = st.sidebar.selectbox("Seleccione Categoría", df["Categoría"].unique())
# ---> 32 fecha_seleccionada = st.sidebar.slider("Rango de Fechas",
#      33                                         min_value=df["Fecha"].min(),
#      34                                         max_value=df["Fecha"].max(),
#      35                                         value=(df["Fecha"].min(), df["Fecha"].max()))
#      37 # Filtrar datos
#      38 datos_filtrados = df[
#      39     (df["Categoría"] == categoria_seleccionada) &
#      40     (df["Fecha"] >= fecha_seleccionada[0]) &
#      41     (df["Fecha"] <= fecha_seleccionada[1])
#      42 ]
#
# File c:\PY\.venv\Lib\site-packages\streamlit\runtime\metrics_util.py:409, in gather_metrics.<locals>.wrapped_func(*args, **kwargs)
#     407         _LOGGER.debug("Failed to collect command telemetry", exc_info=ex)
#     408 try:
# --> 409     result = non_optional_func(*args, **kwargs)
#     410 except RerunException as ex:
#     411     # Duplicated from below, because static analysis tools get confused
#     412     # by deferring the rethrow.
#     413     if tracking_activated and command_telemetry:
#
# File c:\PY\.venv\Lib\site-packages\streamlit\elements\widgets\slider.py:502, in SliderMixin.slider(self, label, min_value, max_value, value, step, format, key, help, on_change, args, kwargs, disabled, label_visibility)
#     352 r"""Display a slider widget.
#     353
#     354 This supports int, float, date, time, and datetime types.
#    (...)
#     499
#     500 """
#     501 ctx = get_script_run_ctx()
# --> 502 return self._slider(
#     503     label=label,
#     504     min_value=min_value,
#     505     max_value=max_value,
#     506     value=value,
#     507     step=step,
#     508     format=format,
#     509     key=key,
#     510     help=help,
#     511     on_change=on_change,
#     512     args=args,
#     513     kwargs=kwargs,
#     514     disabled=disabled,
#     515     label_visibility=label_visibility,
#     516     ctx=ctx,
#     517 )
#
# File c:\PY\.venv\Lib\site-packages\streamlit\elements\widgets\slider.py:614, in SliderMixin._slider(self, label, min_value, max_value, value, step, format, key, help, on_change, args, kwargs, disabled, label_visibility, ctx)
#     611 def all_same_type(items):
#     612     return len(set(map(value_to_generic_type, items))) < 2
# --> 614 if not all_same_type(value):
#     615     raise StreamlitAPIException(
#     616         "Slider tuple/list components must be of the same type.\n"
#     617         f"But were: {list(map(type, value))}"
#     618     )
#     620 if len(value) == 0:
#
# File c:\PY\.venv\Lib\site-packages\streamlit\elements\widgets\slider.py:612, in SliderMixin._slider.<locals>.all_same_type(items)
#     611 def all_same_type(items):
# --> 612     return len(set(map(value_to_generic_type, items))) < 2
#
# File c:\PY\.venv\Lib\site-packages\streamlit\elements\widgets\slider.py:609, in SliderMixin._slider.<locals>.value_to_generic_type(v)
#     607     return SUPPORTED_TYPES[Real]
#     608 else:
# --> 609     return SUPPORTED_TYPES[type(v)]
#
# KeyError: <class 'pandas._libs.tslibs.timestamps.Timestamp'>
