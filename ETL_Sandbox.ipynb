# %% [markdown]
# # TRANSFERIR ARCHIVOS en PYTHON

# %%
# OBTENER PARÁMETROS de la CONEXIÓN

import pyodbc
from dotenv import dotenv_values

secrets = dotenv_values(".env")
local_secrets = dotenv_values(".env.dev")

DRIVER = secrets["DRIVER2"]
SERVIDOR = secrets["SERVIDOR2"]
PUERTO = secrets["PUERTO2"]
BASE = secrets["BASE2"]
USUARIO = secrets["USUARIO2"]
CONTRASENA = secrets["CONTRASENA2"]

constr = f'DRIVER={DRIVER};SERVER={SERVIDOR};PORT={PUERTO};DATABASE={BASE};UID={USUARIO};PWD={CONTRASENA}'

conn_str = (
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=10.54.200.90;"
     "PORT=1433;"
    "DATABASE=data-sync;"
    "UID=eettlin;"
    "PWD=lOc4l_eXt$24;"
)


print (constr)
print (conn_str)
# Out:
# DRIVER={ODBC Driver 17 for SQL Server};SERVER=10.54.200.90;PORT=1433;DATABASE=data-sync;UID=eettlin;PWD=lOc4l_eXt$24;
# DRIVER={ODBC Driver 17 for SQL Server};SERVER=10.54.200.90;PORT=1433;DATABASE=data-sync;UID=eettlin;PWD=lOc4l_eXt$24;

# %%
import pandas as pd
import pyodbc

# Configuración de conexión
conn_str = f'DRIVER={DRIVER};SERVER={SERVIDOR};PORT={PUERTO};DATBASE={BASE};UID={USUARIO};PWD={CONTRASENA}'

conn = pyodbc.connect(conn_str)

query = """
-- Consulta con datos históricos y actuales
SELECT [id_tienda]
      ,[suc_nombre]
      ,[sucursal]
      ,[formato]
      ,[f_actividad]
      ,[terreno]
      ,[cubierta]
      ,[s_cubierta]
      ,[playa]
      ,[salon]
      ,[deposito]
      ,[check_outs]
      ,[direccion]
      ,[postal]
      ,[f_cierre]
  FROM [data-sync].[dbo].[M_SUCURSALES_EXT];
"""
data = pd.read_sql(query, conn)
conn.close()
# Out:
# C:\Users\eduar\AppData\Local\Temp\ipykernel_20372\1839726219.py:37: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql(query, conn)

# %%
data.head()

# %% [markdown]
# ## RUTINA FINAL

# %%
import pandas as pd
import pyodbc
import psycopg2
from sqlalchemy import create_engine

# Conexión a SQL Server
conn_str_sqlserver = (
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=10.54.200.90;"
    "PORT=1433;"
    "DATABASE=data-sync;"
    "UID=eettlin;"
    "PWD=lOc4l_eXt$24;"
)

try:
    conn_sqlserver = pyodbc.connect(conn_str_sqlserver)
    print("Conexión a SQL Server exitosa.")
except Exception as e:
    print("Error al conectar a SQL Server:", e)
    exit()

# Consulta en SQL Server
query = """
SELECT [id_tienda],
       [suc_nombre],
       [sucursal],
       [formato],
       [f_actividad],
       [terreno],
       [cubierta],
       [s_cubierta],
       [playa],
       [salon],
       [deposito],
       [check_outs],
       [direccion],
       [postal],
       [f_cierre]
  FROM [data-sync].[dbo].[M_SUCURSALES_EXT];
"""

try:
    data = pd.read_sql(query, conn_sqlserver)
    print("Datos extraídos de SQL Server correctamente.")
except Exception as e:
    print("Error al ejecutar la consulta en SQL Server:", e)
    conn_sqlserver.close()
    exit()

# Cerrar conexión a SQL Server
conn_sqlserver.close()
# Out:
# Conexión a SQL Server exitosa.
# Datos extraídos de SQL Server correctamente.
# C:\Users\eduar\AppData\Local\Temp\ipykernel_20372\2711210567.py:44: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql(query, conn_sqlserver)

# %%
# Conexión a PostgreSQL
conn_str_postgres = "postgresql://postgres:aladelta10$@140.99.164.229:5432/diarco_data"

try:
    engine = create_engine(conn_str_postgres)
    conn_postgres = engine.connect()
    print("Conexión a PostgreSQL exitosa.")
except Exception as e:
    print("Error al conectar a PostgreSQL:", e)
    exit()

# Insertar datos en la tabla m_sucursales_ext
try:
    data.to_sql('m_sucursales_ext', engine, if_exists='append', index=False)
    print("Datos insertados en PostgreSQL correctamente.")
except Exception as e:
    print("Error al insertar datos en PostgreSQL:", e)
finally:
    conn_postgres.close()
    print("Conexión a PostgreSQL cerrada.")
# Out:
# Conexión a PostgreSQL exitosa.
# Datos insertados en PostgreSQL correctamente.
# Conexión a PostgreSQL cerrada.

# %% [markdown]
# ## RECUPERO_PROVEEDORES

# %%
import pandas as pd
import pyodbc
import psycopg2
from sqlalchemy import create_engine

# Conexión a SQL Server
conn_str_sqlserver = (
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=10.54.200.90;"
    "PORT=1433;"
    "DATABASE=data-sync;"
    "UID=eettlin;"
    "PWD=lOc4l_eXt$24;"
)

try:
    conn_sqlserver = pyodbc.connect(conn_str_sqlserver)
    print("Conexión a SQL Server exitosa.")
except Exception as e:
    print("Error al conectar a SQL Server:", e)
    exit()

# Consulta en SQL Server
query = """
SELECT [C_PROVEEDOR]
      ,[F_ALTA_SIST]
      ,[N_CLIENTE]
      ,[C_DOC]
      ,[U_DOC_PREFIJO_CONTROLADOR_FISCAL]
      ,[U_DOC_SUFIJO_CONTROLADOR_FISCAL]
      ,[C_DOC_LETRA]
      ,[C_SUCU_ORIG_ALTA]
      ,[C_USUARIO]
      ,[I_TOTAL]
      ,[I_NETO_1]
      ,[I_NETO_2]
      ,[D_OBSERVACION]
      ,[ORIGEN]
      ,[FLAG_1]
      ,[FLAG_2]
      ,[FLAG_3]
  FROM [dbo].[T_RECUPERO_PROVEEDORES];
"""

try:
    data = pd.read_sql(query, conn_sqlserver)
    print("Datos extraídos de SQL Server correctamente.")
except Exception as e:
    print("Error al ejecutar la consulta en SQL Server:", e)
    conn_sqlserver.close()
    exit()

# Cerrar conexión a SQL Server
conn_sqlserver.close()
# Out:
# Conexión a SQL Server exitosa.
# C:\Users\eduar\AppData\Local\Temp\ipykernel_16732\1369103631.py:46: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql(query, conn_sqlserver)
# Datos extraídos de SQL Server correctamente.

# %%
data.columns = data.columns.str.lower()
data.head()
# Out:
#    c_proveedor             f_alta_sist  \
# 0         47.0 2024-10-16 15:14:17.847
# 1         47.0 2024-10-16 15:14:18.197
# 2        258.0 2024-12-04 08:56:40.110
# 3        258.0 2024-12-04 08:56:40.457
# 4         47.0 2025-01-09 11:01:52.520
#
#                                            n_cliente  c_doc  \
# 0  SOFTYS ARGENTINA S.A                          ...    1.0
# 1  SOFTYS ARGENTINA S.A                          ...    1.0
# 2  SED METAL SRL.                                ...    1.0
# 3  SED METAL SRL.                                ...    1.0
# 4  SOFTYS ARGENTINA S.A                          ...    1.0
#
#    u_doc_prefijo_controlador_fiscal  u_doc_sufijo_controlador_fiscal  \
# 0                            2033.0                          75559.0
# 1                            2033.0                          75560.0
# 2                            2033.0                          77507.0
# 3                            2033.0                          77508.0
# 4                            2033.0                          78941.0
#
#   c_doc_letra  c_sucu_orig_alta   c_usuario      i_total   i_neto_1  i_neto_2  \
# 0           A               1.0  SISTEMAS     5947974.30  4747934.0       0.0
# 1           A               1.0  SISTEMAS     8463225.00  6755717.0       0.0
# 2           A               1.0  SISTEMAS      794000.75   639838.5       0.0
# 3           A               1.0  SISTEMAS      543696.63   438133.1       0.0
# 4           A               1.0  SISTEMAS    10678151.20  8523766.0       0.0
#
#                                        d_observacion                origen  \
# 0  Generado por comprobante: X-0000-00018527     ...  de Facturas Emitidas
# 1  Generado por comprobante: X-0000-00018528     ...  de Facturas Emitidas
# 2  Generado por comprobante: X-0000-00018538     ...  de Facturas Emitidas
# 3  Generado por comprobante: X-0000-00018539     ...  de Facturas Emitidas
# 4  Generado por comprobante: X-0000-00018550     ...  de Facturas Emitidas
#
#    flag_1  flag_2  flag_3
# 0       1       0       0
# 1       1       0       0
# 2       1       0       0
# 3       1       0       0
# 4       1       0       0

# %%
# Conexión a PostgreSQL
conn_str_postgres = "postgresql://postgres:aladelta10$@140.99.164.229:5432/diarco_data"

try:
    engine = create_engine(conn_str_postgres)
    conn_postgres = engine.connect()
    print("Conexión a PostgreSQL exitosa.")
except Exception as e:
    print("Error al conectar a PostgreSQL:", e)
    exit()

# Insertar datos en la tabla m_sucursales_ext
try:
    data.to_sql('t_recupero_proveedores', engine, if_exists='append', index=False)
    print("Datos insertados en PostgreSQL correctamente.")
except Exception as e:
    print("Error al insertar datos en PostgreSQL:", e)
finally:
    conn_postgres.close()
    print("Conexión a PostgreSQL cerrada.")
# Out:
# Conexión a PostgreSQL exitosa.
# Datos insertados en PostgreSQL correctamente.
# Conexión a PostgreSQL cerrada.

# %% [markdown]
# ## FALTANTES SUBRUBRO_LOCAL

# %%
# Conexión a SQL Server
conn_str_sqlserver = (
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=10.54.200.90;"
    "PORT=1433;"
    "DATABASE=data-sync;"
    "UID=eettlin;"
    "PWD=lOc4l_eXt$24;"
)

try:
    conn_sqlserver = pyodbc.connect(conn_str_sqlserver)
    print("Conexión a SQL Server exitosa.")
except Exception as e:
    print("Error al conectar a SQL Server:", e)
    exit()

# Consulta en SQL Server
query = """
SELECT [c_sucu_empr]
      ,[vnfamilia]
      ,[vnrubro]
      ,[vnsubrubro]
      ,[habilitada]
      ,[SinStock]
      ,[Porcentaje]
  FROM [dbo].[T_FALTANTES_SUBRUBRO_LOCAL];
"""

try:
    data = pd.read_sql(query, conn_sqlserver)
    print("Datos extraídos de SQL Server correctamente.")
except Exception as e:
    print("Error al ejecutar la consulta en SQL Server:", e)
    conn_sqlserver.close()
    exit()

# Cerrar conexión a SQL Server
conn_sqlserver.close()

data.columns = data.columns.str.lower()
data.head()

# Conexión a PostgreSQL
conn_str_postgres = "postgresql://postgres:aladelta10$@140.99.164.229:5432/diarco_data"

try:
    engine = create_engine(conn_str_postgres)
    conn_postgres = engine.connect()
    print("Conexión a PostgreSQL exitosa.")
except Exception as e:
    print("Error al conectar a PostgreSQL:", e)
    exit()

# Insertar datos en la tabla m_sucursales_ext
try:
    data.to_sql('t_faltantes_subrubro_local ', engine, if_exists='append', index=False)
    print("Datos insertados en PostgreSQL correctamente.")
except Exception as e:
    print("Error al insertar datos en PostgreSQL:", e)
finally:
    conn_postgres.close()
    print("Conexión a PostgreSQL cerrada.")
# Out:
# Conexión a SQL Server exitosa.
# C:\Users\eduar\AppData\Local\Temp\ipykernel_16732\3843677224.py:31: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql(query, conn_sqlserver)
# Datos extraídos de SQL Server correctamente.
# Conexión a PostgreSQL exitosa.
# Datos insertados en PostgreSQL correctamente.
# Conexión a PostgreSQL cerrada.
